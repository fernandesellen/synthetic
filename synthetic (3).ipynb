# %%
! pip install verde harmonica pandas matplotlib
# Out:
# Requirement already satisfied: verde in c:\users\skill\miniforge3\lib\site-packages (1.8.0)
# Requirement already satisfied: harmonica in c:\users\skill\miniforge3\lib\site-packages (0.6.0)
# Requirement already satisfied: pandas in c:\users\skill\miniforge3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\skill\miniforge3\lib\site-packages (3.8.4)
# Requirement already satisfied: numpy>=1.19 in c:\users\skill\miniforge3\lib\site-packages (from verde) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\skill\miniforge3\lib\site-packages (from verde) (1.13.0)
# Requirement already satisfied: xarray>=0.16 in c:\users\skill\miniforge3\lib\site-packages (from verde) (2024.3.0)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\skill\miniforge3\lib\site-packages (from verde) (1.4.2)
# Requirement already satisfied: pooch>=1.2 in c:\users\skill\miniforge3\lib\site-packages (from verde) (1.8.1)
# Requirement already satisfied: dask>=2021.05.0 in c:\users\skill\miniforge3\lib\site-packages (from verde) (2024.4.1)
# Requirement already satisfied: numba>=0.52 in c:\users\skill\miniforge3\lib\site-packages (from harmonica) (0.59.1)
# Requirement already satisfied: xrft>=1.0 in c:\users\skill\miniforge3\lib\site-packages (from harmonica) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\skill\miniforge3\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\skill\miniforge3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\skill\miniforge3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\skill\miniforge3\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\skill\miniforge3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\skill\miniforge3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\skill\miniforge3\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\skill\miniforge3\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\skill\miniforge3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\skill\miniforge3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: click>=8.1 in c:\users\skill\miniforge3\lib\site-packages (from dask>=2021.05.0->verde) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\skill\miniforge3\lib\site-packages (from dask>=2021.05.0->verde) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\skill\miniforge3\lib\site-packages (from dask>=2021.05.0->verde) (2024.3.1)
# Requirement already satisfied: partd>=1.2.0 in c:\users\skill\miniforge3\lib\site-packages (from dask>=2021.05.0->verde) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\skill\miniforge3\lib\site-packages (from dask>=2021.05.0->verde) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\skill\miniforge3\lib\site-packages (from dask>=2021.05.0->verde) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\skill\miniforge3\lib\site-packages (from dask>=2021.05.0->verde) (7.1.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\skill\miniforge3\lib\site-packages (from numba>=0.52->harmonica) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\skill\miniforge3\lib\site-packages (from pooch>=1.2->verde) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\skill\miniforge3\lib\site-packages (from pooch>=1.2->verde) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\skill\miniforge3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\skill\miniforge3\lib\site-packages (from scikit-learn>=0.24->verde) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\skill\miniforge3\lib\site-packages (from scikit-learn>=0.24->verde) (3.4.0)
# Requirement already satisfied: colorama in c:\users\skill\miniforge3\lib\site-packages (from click>=8.1->dask>=2021.05.0->verde) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\skill\miniforge3\lib\site-packages (from importlib-metadata>=4.13.0->dask>=2021.05.0->verde) (3.17.0)
# Requirement already satisfied: locket in c:\users\skill\miniforge3\lib\site-packages (from partd>=1.2.0->dask>=2021.05.0->verde) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\skill\miniforge3\lib\site-packages (from requests>=2.19.0->pooch>=1.2->verde) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\skill\miniforge3\lib\site-packages (from requests>=2.19.0->pooch>=1.2->verde) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\skill\miniforge3\lib\site-packages (from requests>=2.19.0->pooch>=1.2->verde) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\skill\miniforge3\lib\site-packages (from requests>=2.19.0->pooch>=1.2->verde) (2024.2.2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import harmonica as hm
import verde as vd
import pandas as pd

# %%
region = [0, 100e3, 0, 90e3]
coordinates = vd.scatter_points(region, size=1000, extra_coords=1000)

plt.plot(coordinates[0], coordinates[1], ".k")

# %%
len(coordinates[0])
# Out:
# 1000

# %%
prismas = [
    [10e3, 15e3, 20e3, 35e3, -1e3,  0],
    [60e3, 80e3, 50e3, 70e3, -2e3,  -0.5e3],
]
densidades = [500, -300]
gz = hm.prism_gravity(coordinates, prismas, densidades, field="g_z")

# %%
plt.scatter(coordinates[0], coordinates[1], s=5, c=gz)
plt.colorbar()

# %%
# Fontes equivalentes
fontes = hm.EquivalentSourcesGB(damping=1,depth=1e3)
altura = np.zeros(1000)
fontes.fit([coordinates[0],coordinates[1],altura],data=gz) # o que faz essa funcao .fit?
# Out:
# EquivalentSourcesGB(damping=1, depth=1000.0)

# %%
grid_coords_eq = vd.grid_coordinates(region,spacing=1e3,extra_coords=1000)
gz_grid_eq = fontes.grid(grid_coords_eq,data_names="g_z")
gz_grid_eq.g_z.plot()

# %%
# Malha regular
grid_coords = vd.grid_coordinates(region, spacing=1e3, extra_coords=1000)
gz_grid = hm.prism_gravity(grid_coords, prismas, densidades, field="g_z")
grid_true = vd.make_xarray_grid(grid_coords, gz_grid, data_names="g_z", extra_coords_names="upward")
grid_true.g_z.plot()

# %%
# Diferença
dif = grid_true - gz_grid_eq
dif.g_z.plot()

# %%
# Using cross-validation to evaluate how well 
# these equivalent sources can accurately predict the values of the field
score_first_guess = np.mean(
    vd.cross_val_score(
        fontes,
        coordinates,
        gz,
    )
)
R_2 = score_first_guess
R_2
# Out:
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# 0.9566972382468828

# %%
# Block-averaged sources
# This method divides the survey region (defined by the data) into square blocks of equal size, 
# computes the median coordinates of the data points that fall inside each block and 
# locates one source beneath every averaged position. This way, we define one equivalent source per block, 
# with the exception of empty blocks that won’t get any source.

fontes_block = hm.EquivalentSourcesGB(damping=1,depth=1e3,block_size=500, depth_type="constant")
# These sources were set at a constant depth of 1km bellow the zeroth height and with a damping equal to 1.

fontes_block.fit([coordinates[0],coordinates[1],altura],data=gz)
# During this step the point sources are created through the block averaging process.
# Out:
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# EquivalentSourcesGB(block_size=500, damping=1, depth=1000.0,
#                     depth_type='constant')

# %%
# Using cross-validation to evaluate how well 
# these equivalent sources can accurately predict the values of the field
score_first_guess = np.mean(
    vd.cross_val_score(
        fontes_block,
        coordinates,
        gz,
    )
)
R_2 = score_first_guess
# Bloco de 500m
print(f"Number of sources = {fontes_block.points_[0].size}")
print(f"R_2 = {R_2}")
# Out:
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# Number of sources = 990
# R_2 = 0.9823961234154428
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)

# %%
# Blocos de 1000m
fontes_block = hm.EquivalentSourcesGB(damping=1,depth=1e3,block_size=1e3, depth_type="constant")
# These sources were set at a constant depth of 1km bellow the zeroth height and with a damping equal to 1.

fontes_block.fit([coordinates[0],coordinates[1],altura],data=gz)
# During this step the point sources are created through the block averaging process.


# Using cross-validation to evaluate how well 
# these equivalent sources can accurately predict the values of the field
score_first_guess = np.mean(
    vd.cross_val_score(
        fontes_block,
        coordinates,
        gz,
    )
)
R_2 = score_first_guess
print(f"Number of sources = {fontes_block.points_[0].size}")
print(f"R_2 = {R_2}")
# Out:
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# Number of sources = 938
# R_2 = 0.9822289372090387
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)

# %%
# Blocos de 2500m
fontes_block = hm.EquivalentSourcesGB(damping=1,depth=1e3,block_size=2.5e3, depth_type="constant")
# These sources were set at a constant depth of 1km bellow the zeroth height and with a damping equal to 1.

fontes_block.fit([coordinates[0],coordinates[1],altura],data=gz)
# During this step the point sources are created through the block averaging process.


# Using cross-validation to evaluate how well 
# these equivalent sources can accurately predict the values of the field
score_first_guess = np.mean(
    vd.cross_val_score(
        fontes_block,
        coordinates,
        gz,
    )
)
R_2 = score_first_guess
print(f"Number of sources = {fontes_block.points_[0].size}")
print(f"R_2 = {R_2}")
# Out:
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# Number of sources = 720
# R_2 = 0.9787676232822214
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)

# %%
# Blocos de 5000m
fontes_block = hm.EquivalentSourcesGB(damping=1,depth=1e3,block_size=5e3, depth_type="constant")
# These sources were set at a constant depth of 1km bellow the zeroth height and with a damping equal to 1.

fontes_block.fit([coordinates[0],coordinates[1],altura],data=gz)
# During this step the point sources are created through the block averaging process.


# Using cross-validation to evaluate how well 
# these equivalent sources can accurately predict the values of the field
score_first_guess = np.mean(
    vd.cross_val_score(
        fontes_block,
        coordinates,
        gz,
    )
)
R_2 = score_first_guess
print(f"Number of sources = {fontes_block.points_[0].size}")
print(f"R_2 = {R_2}")
# Out:
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# Number of sources = 335
# R_2 = 0.9609202768576394
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)

# %%
R_2 = []
sources = []

block = [block for block in range(50,102050,2000)]
for block_size in block:
    fontes_block = hm.EquivalentSourcesGB(damping=1,depth=1e3,block_size=block_size, depth_type="constant")
    # These sources were set at a constant depth of 1km bellow the zeroth height and with a damping equal to 1.

    fontes_block.fit([coordinates[0],coordinates[1],altura],data=gz)
    # During this step the point sources are created through the block averaging process.

    # Using cross-validation to evaluate how well 
    # these equivalent sources can accurately predict the values of the field
    score = np.mean(
        vd.cross_val_score(
            fontes_block,
            coordinates,
            gz,
        )
    )
    R_2.append(score)
    sources.append(fontes_block.points_[0].size)
# Out:
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.42695e-30): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(3, 4).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(3, 4).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(3, 4).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.65084e-31): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(3, 4).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(2, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 3).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.90616e-30): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.37289e-30): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.37289e-30): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.37289e-30): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\base\least_squares.py:57: UserWarning: Under-determined problem detected (ndata, nparams)=(1, 2).
#   warn(
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
# ...
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:179: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   blocked = pd.DataFrame(columns).groupby("block").aggregate(reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\blockreduce.py:236: FutureWarning: The provided callable <function median at 0x000002A19C9C2EF0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = table.groupby("block").aggregate(self.reduction)
# C:\Users\skill\miniforge3\lib\site-packages\verde\model_selection.py:784: FutureWarning: The default scoring will change from R² to negative root mean squared error (RMSE) in Verde 2.0.0. This may change model selection results slightly.
#   score = estimator.score(*test_data)

# %%
plt.plot(block,R_2)
plt.legend()
plt.xlabel('Tamanho do bloco')
plt.ylabel('Erro')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Erro')

# %%
plt.plot(block,sources)
plt.legend()
plt.xlabel('Tamanho do bloco')
plt.ylabel('Numero de fontes')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Numero de fontes')

# %%
plt.plot(sources,R_2)
plt.legend()
plt.xlabel('Numero de fontes')
plt.ylabel('Erro')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Erro')

# %%
plt.plot(sources,R_2)
plt.legend()
plt.xlabel('Numero de fontes')
plt.xlim(-3,150)
plt.ylabel('Erro')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Erro')

# %%
# Splitting data randomly into train and test sets

test_size = 0.2
# Assign 20% of the data to the testing set.

train, test = vd.train_test_split(
    coordinates, gz, test_size=test_size, random_state=123
)

print(f"Train: {train[0][0].size} and test: {test[0][0].size} size for random splits")

# Assign the data to blocks and then split the
# blocks randomly. To do this, specify the size of the blocks using the
# 'spacing' argument.
train_block, test_block = vd.train_test_split(
    coordinates,
    values,
    spacing=10 / 60,
    test_size=test_size,
    random_state=213,
)
# Out:
# Train: 800 and test: 200 size for random splits
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 17
#      10 print(f"Train: {train[0][0].size} and test: {test[0][0].size} size for random splits")
#      12 # Assign the data to blocks and then split the
#      13 # blocks randomly. To do this, specify the size of the blocks using the
#      14 # 'spacing' argument.
#      15 train_block, test_block = vd.train_test_split(
#      16     coordinates,
# ---> 17     values,
#      18     spacing=10 / 60,
#      19     test_size=test_size,
#      20     random_state=213,
#      21 )
#
# NameError: name 'values' is not defined
